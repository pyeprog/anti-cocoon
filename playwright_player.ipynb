# %%
from playwright.async_api import async_playwright
player = async_playwright()

# %% [markdown]
# # Update session file

# %%
p = await player.__aenter__()
browser = await p.chromium.launch(headless=False)
context = await browser.new_context()
page = await context.new_page()

# %%
await page.goto("https://www.bilibili.com")
# Out:
# <Response url='https://www.bilibili.com/' request=<Request url='https://www.bilibili.com/' method='GET'>>

# %%
await context.storage_state(path='bili.json')
# Out:
# {'cookies': [{'name': 'buvid3',
#    'value': 'CC25D4C8-C7D0-0E11-B583-111A93FEFB4271721infoc',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1787469771.604763,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'b_nut',
#    'value': '1755933771',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1787469771.60525,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'b_lsid',
#    'value': 'F4F210F85_198D5CF07B2',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': -1,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': '_uuid',
#    'value': 'D724FD8A-EBBA-896D-D47C-710A4166B26E371708infoc',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1787469771,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'buvid_fp',
#    'value': 'bb3f12920c484262ff1145f95f1fc5a2',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1790493771.803103,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'enable_web_push',
#    'value': 'DISABLE',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1787469771,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'home_feed_column',
#    'value': '4',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1787469771,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'browser_resolution',
#    'value': '1280-720',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1787469771,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'bmg_af_switch',
#    'value': '1',
#    'domain': 'www.bilibili.com',
#    'path': '/',
#    'expires': -1,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'bmg_src_def_domain',
#    'value': 'i1.hdslb.com',
#    'domain': 'www.bilibili.com',
#    'path': '/',
#    'expires': -1,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'buvid4',
#    'value': '7103D5D4-9CD2-A3F2-6F0C-E1EC3A754F8372323-025082315-ecwQDui1RrYNN5OfE3kNXA%3D%3D',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1790494943.108043,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'bmg_af_switch',
#    'value': '1',
#    'domain': 'search.bilibili.com',
#    'path': '/',
#    'expires': -1,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'bmg_src_def_domain',
#    'value': 'i1.hdslb.com',
#    'domain': 'search.bilibili.com',
#    'path': '/',
#    'expires': -1,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'bili_ticket',
#    'value': 'eyJhbGciOiJIUzI1NiIsImtpZCI6InMwMyIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3NTYxOTI5OTAsImlhdCI6MTc1NTkzMzczMCwicGx0IjotMX0.P1gACpgkNPfbMDXm6PBoS-0q__OuVrSS3pgYf-Bp_GY',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1756192990,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'bili_ticket_expires',
#    'value': '1756192930',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1756192990,
#    'httpOnly': False,
#    'secure': False,
#    'sameSite': 'Lax'},
#   {'name': 'SESSDATA',
#    'value': 'bff31d05%2C1771486942%2Cef9ba%2A82CjA9RRcZVlH4yz93Ctnss2PB_EeFr078UqTtNfdAOpl-p_pP-flmh-l-NcbBKgGqIJ4SVjllYlU2SHpIbV82cHAxckVtWjE1QmNub0FUOGJ5eGhIeGxQNkJrQlBFbUFvNmNIQ1A3N3RHZlhZMjlSVndxaTBabzl4ZzlzdUpLNkFnb1VBRXo1OWZBIIEC',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1771486942.097291,
#    'httpOnly': True,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'bili_jct',
#    'value': 'a7805e3f28222a1b1e7613a3f0fb679e',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1771486942.097354,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'DedeUserID',
#    'value': '427857',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1771486942.097381,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'DedeUserID__ckMd5',
#    'value': 'b9b756c8c145dae7',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1771486942.097403,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'sid',
#    'value': '7o0eo3ac',
#    'domain': '.bilibili.com',
#    'path': '/',
#    'expires': 1771486942.097422,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'SESSDATA',
#    'value': 'bff31d05%2C1771486942%2Cef9ba%2A82CjA9RRcZVlH4yz93Ctnss2PB_EeFr078UqTtNfdAOpl-p_pP-flmh-l-NcbBKgGqIJ4SVmljbGVmTzJrMmE2TS1wcjlpZ2F4djFVOXdPcGFMWXZKV1hjc0pQTnF5dGxuNmVYMXFQZHhlbUpsaFpOdUpvamVvX0NpVWdTMzJHQUg4ZDNMN2xxSWVBIIEC',
#    'domain': '.bilicomic.com',
#    'path': '/',
#    'expires': 1771486942.37935,
#    'httpOnly': True,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'bili_jct',
#    'value': 'a7805e3f28222a1b1e7613a3f0fb679e',
#    'domain': '.bilicomic.com',
#    'path': '/',
#    'expires': 1771486942.379438,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'DedeUserID',
#    'value': '427857',
#    'domain': '.bilicomic.com',
#    'path': '/',
#    'expires': 1771486942.379462,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'DedeUserID__ckMd5',
#    'value': 'b9b756c8c145dae7',
#    'domain': '.bilicomic.com',
#    'path': '/',
#    'expires': 1771486942.379482,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'sid',
#    'value': '866flki6',
#    'domain': '.bilicomic.com',
#    'path': '/',
#    'expires': 1771486942.3795,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'SESSDATA',
#    'value': 'bff31d05%2C1771486942%2Cef9ba%2A82CjA9RRcZVlH4yz93Ctnss2PB_EeFr078UqTtNfdAOpl-p_pP-flmh-l-NcbBKgGqIJ4SVkF2T2Q1allVV0R5YzRqVkZ1TjB1V2hHZ0liZmxxajNXUzhtbDhJU2ZURlg3TW5lOWZMZjl4c3dRdXBxNmliaXR1by15aE4xcTVMOUNRTWd3aUxfbUhRIIEC',
#    'domain': '.biligame.com',
#    'path': '/',
#    'expires': 1771486942.408711,
#    'httpOnly': True,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'bili_jct',
#    'value': 'a7805e3f28222a1b1e7613a3f0fb679e',
#    'domain': '.biligame.com',
#    'path': '/',
#    'expires': 1771486942.408784,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'DedeUserID',
#    'value': '427857',
#    'domain': '.biligame.com',
#    'path': '/',
#    'expires': 1771486942.408807,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'DedeUserID__ckMd5',
#    'value': 'b9b756c8c145dae7',
#    'domain': '.biligame.com',
#    'path': '/',
#    'expires': 1771486942.408825,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'sid',
#    'value': 'grgs2zjv',
#    'domain': '.biligame.com',
#    'path': '/',
#    'expires': 1771486942.408843,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'SESSDATA',
#    'value': 'bff31d05%2C1771486942%2Cef9ba%2A82CjA9RRcZVlH4yz93Ctnss2PB_EeFr078UqTtNfdAOpl-p_pP-flmh-l-NcbBKgGqIJ4SVlkwUVI4TXVGX1R5VlltcjJRUDF6d19DcVJiRk1rc1lTY3dua2toc2NKd2xXRWZ2WnRYQ0lXY2dVOUQyb29UdlRyTFJBckVTTEhQMUlreUVwb0pxYWp3IIEC',
#    'domain': '.bilibili.cn',
#    'path': '/',
#    'expires': 1771486942.470806,
#    'httpOnly': True,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'bili_jct',
#    'value': 'a7805e3f28222a1b1e7613a3f0fb679e',
#    'domain': '.bilibili.cn',
#    'path': '/',
#    'expires': 1771486942.4709,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'DedeUserID',
#    'value': '427857',
#    'domain': '.bilibili.cn',
#    'path': '/',
#    'expires': 1771486942.470927,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'DedeUserID__ckMd5',
#    'value': 'b9b756c8c145dae7',
#    'domain': '.bilibili.cn',
#    'path': '/',
#    'expires': 1771486942.47096,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'sid',
#    'value': 'h91697kg',
#    'domain': '.bilibili.cn',
#    'path': '/',
#    'expires': 1771486942.470986,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'SESSDATA',
#    'value': 'bff31d05%2C1771486942%2Cef9ba%2A82CjA9RRcZVlH4yz93Ctnss2PB_EeFr078UqTtNfdAOpl-p_pP-flmh-l-NcbBKgGqIJ4SVmpFTU5oUWpyaXE4TXprMEw4bzI1UmxxdXVSTWQxeks0UzRDbk5rTlpwNWMzTEhUNFI4ZkhDV05oV0xhS2pValZmOVRaYWp0eHFBYUZvZGVtOFF1STVBIIEC',
#    'domain': '.bilicomics.com',
#    'path': '/',
#    'expires': 1771486942.482757,
#    'httpOnly': True,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'bili_jct',
#    'value': 'a7805e3f28222a1b1e7613a3f0fb679e',
#    'domain': '.bilicomics.com',
#    'path': '/',
#    'expires': 1771486942.482847,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'DedeUserID',
#    'value': '427857',
#    'domain': '.bilicomics.com',
#    'path': '/',
#    'expires': 1771486942.482879,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'DedeUserID__ckMd5',
#    'value': 'b9b756c8c145dae7',
#    'domain': '.bilicomics.com',
#    'path': '/',
#    'expires': 1771486942.482905,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'},
#   {'name': 'sid',
#    'value': '7djntgk6',
#    'domain': '.bilicomics.com',
#    'path': '/',
#    'expires': 1771486942.482926,
#    'httpOnly': False,
#    'secure': True,
#    'sameSite': 'None'}],
#  'origins': [{'origin': 'https://www.bilibili.com',
#    'localStorage': [{'name': 'wbi_sub_url',
#      'value': 'https://i0.hdslb.com/bfs/wbi/4932caff0ff746eab6f01bf08b70ac45.png'},
#     {'name': 'secure_collect_last_report_time_CC25D4C8-C7D0-0E11-B583-111A93FEFB4271721infoc',
#      'value': '1755933772494'},
#     {'name': 'bmg_af_wl', 'value': '[1,2,2]'},
#     {'name': 'BILI_MIRROR_REPORT_POOL', 'value': '{}'},
#     {'name': 'wbi_img_url',
#      'value': 'https://i0.hdslb.com/bfs/wbi/7cd084941338484aae1ad9425b84077c.png'},
#     {'name': 'ac_time_value', 'value': 'b7245dd77a06c3bc2b2e5ad014120182'},
#     {'name': 'KV_CONFIG_SDK',
#      'value': '{"333.1333_0":{"timestamp":1755933771957,"lastUsed":1755934942833,"value":{"bilimirror.minilogin":"{\\"buvid\\":[\\"B6771AA6-7CCD-4EF2-BA5B-1FDE9A25F49A49120infoc\\",\\"D025573B-8686-0D9D-48DB-0C84BBB5544A45226infoc\\",\\"9BD89CEC-4C19-E243-63B3-9A69417B70A458220infoc\\",\\"4AD0D8C7-D936-FB67-4C33-7A13C004E84478537infoc\\",\\"84AF2B23-9DC9-0717-A474-BCB7A866198994970infoc\\",\\"F4373CB5-E491-2C2A-0541-2FFFC3DF2FCC71448infoc\\"],\\"rate\\":0}","bilimirror.toplist":"{\\"playLogUmd\\":\\"https://s1.hdslb.com/bfs/static/log-manipulator@0.2.1/index.js\\",\\"trackGray\\":0,\\"trackGrayV2\\":1}","bilimirror.whitelist":"{\\"white\\":{\\"rejection\\":[\\"extension\\",\\"maximum\\"],\\"error\\":[\\"extension\\"],\\"resource\\":[\\"extension\\",\\"localhost\\"]},\\"retry\\":[],\\"performance\\":1,\\"techpv\\":5,\\"poll\\":5,\\"userLog\\":[],\\"track\\":{\\"mid\\":[\\"*\\"],\\"buvid\\":[]},\\"trackGrayV2\\":1}"},"versionId":"1749114332587","appVersionId":"33942","nscode":0,"appKey":"333.1333","expires":2592000000},"333.1339_
\"life\\",\\"name\\":\\"汽车生活\\",\\"url\\":\\"\\"},{\\"subChannelId\\":190004,\\"tid\\":2109,\\"route\\":\\"tech\\",\\"name\\":\\"汽车技术\\",\\"url\\":\\"\\"},{\\"subChannelId\\":190005,\\"tid\\":2110,\\"route\\":\\"other\\",\\"name\\":\\"汽车综合\\",\\"url\\":\\"\\"}],\\"config\\":{\\"enableSub\\":0}}","channel_list.cinephile":"{\\"channelId\\":12,\\"tid\\":1001,\\"route\\":\\"cinephile\\",\\"name\\":\\"影视\\",\\"url\\":\\"//www.bilibili.com/c/cinephile/\\",\\"icon\\":\\"homeicon/cinephile/1\\",\\"sub\\":[{\\"subChannelId\\":1200 ...
#     {'name': 'secure_collect_report_interval_CC25D4C8-C7D0-0E11-B583-111A93FEFB4271721infoc',
#      'value': '60'},
#     {'name': 'bmg_af_dft', 'value': '"5"'},
#     {'name': 'FIRST_TIME_SEE_WL_PIP', 'value': 'SHOW'},
#     {'name': '__reporter-pb-sample-config',
#      'value': '{"444.8.live-room.chronos.init.before.check":50,"444.8.live-room.uam-player.welcome.failed":50,"333.1334.kv-init.error":1,"444.8.live-room.room-page.live-web-danmaku-tech-report":20}'},
#     {'name': 'wbi_img_urls',
#      'value': 'https://i0.hdslb.com/bfs/wbi/7cd084941338484aae1ad9425b84077c.png-https://i0.hdslb.com/bfs/wbi/4932caff0ff746eab6f01bf08b70ac45.png'}]},
#   {'origin': 'https://search.bilibili.com',
#    'localStorage': [{'name': 'wbi_sub_url',
#      'value': 'https://i0.hdslb.com/bfs/wbi/4932caff0ff746eab6f01bf08b70ac45.png'},
#     {'name': 'secure_collect_last_report_time_CC25D4C8-C7D0-0E11-B583-111A93FEFB4271721infoc',
#      'value': '1755933790475'},
#     {'name': 'bmg_af_wl', 'value': '[1,2,2]'},
#     {'name': 'BILI_MIRROR_REPORT_POOL',
#      'value': '{"333.42.main.mini-login.DATA.successReport":{"type":"custom","mirrorVersion":"2.0.10","_BiliGreyResult_method":"gray","_BiliGreyResult_versionId":"128845","mirrorPolymer":3,"/x/passport-login/web/qrcode/generate":1,"/x/passport-login/captcha":5,"/x/passport-login/web/qrcode/poll":16,"/x/passport-login/web/country":2,"/x/passport-login/web/sms/send":1,"/x/passport-login/web/login/sms":1,"/x/passport-login/web/sso/list":1,"//passport.bilicomic.com/x/passport-login/web/sso/set":1,"//passport.biligame.com/x/passport-login/web/sso/set":1,"//passport.bilibili.cn/x/passport-login/web/sso/set":1,"//passport.bilicomics.com/x/passport-login/web/sso/set":1},"333.337.main.bili-header.DATA.successReport":{"type":"custom","mirrorVersion":"2.0.10","_BiliGreyResult_method":"gray","_BiliGreyResult_versionId":"128845","mirrorPolymer":3,"/x/vip/ads/materials":1,"/x/web-interface/dynamic/entrance":1,"//api.vc.bilibili.com/link_setting/v1/link_setting/get":1,"//api.vc.bilibili.com/x/im/web/msgfeed/unread":1}}'},
#     {'name': 'wbi_img_url',
#      'value': 'https://i0.hdslb.com/bfs/wbi/7cd084941338484aae1ad9425b84077c.png'},
#     {'name': 'KV_CONFIG_SDK',
\":[{\\"condition\\":[{\\"field\\":\\"stack\\",\\"operator\\":\\"contains\\",\\"value\\":\\"/bfs/static/player/main\\"}]},{\\"condition\\":[{\\"field\\":\\"stack\\",\\"operator\\":\\"contains\\",\\"value\\":\\"/bfs/static/nc\\"}]}],\\"rejectionError\\":[{\\"condition\\":[{\\"field\\":\\"stack\\",\\"operator\\":\\"contains\\",\\"value\\":\\"/bfs/static/player/main\\"}]},{\\"condition\\":[{\\"field\\":\\"stack\\",\\"operator\\":\\"contains\\",\\"value\\":\\"/bfs/static/nc\\"}]}]},{\\"origin\\":\\"main\\",\\"module\\":\\"bili-header\\",\\"jsError\\":[],\\"rejectionError\\":[{\\"condition\\":[{\\"field\\":\\"stack\\",\\"operator\\":\\"contains\\",\\"value\\":\\"bili-header\\"}]}]}]}","feedsearch.disable":"0"},"versionId":"1750323138274","appVersionId":"34159","nscode":0,"appKey":"333.337","expires":2592000000},"333.1339_9":{"timestamp":1755934165381,"lastUsed":1755934165381,"value":{"user_log.payload_log":"1"},"versionId":"1723104145082","appVersionId":"34219","nscode":9,"appKey":"333.1339","expires":2592000000},"333.1339_2":{"timestamp":1755934943088,"lastUsed":1755934943088,"value":{"channel_list.all":"{  \\"tid\\": 0,  \\"name\\": \\"全部分区\\",  \\"sub\\": []}","channel_list.animal":"{\\"name\\":\\"动物圈\\",\\"channelId\\":18,\\"tid\\":217,\\"url\\":\\"//www.bilibili.com/v/animal\\",\\"icon\\":\\"ChannelAnimal\ ...
#     {'name': 'displayCount_2025_8_427857', 'value': '0'},
#     {'name': 'secure_collect_report_interval_CC25D4C8-C7D0-0E11-B583-111A93FEFB4271721infoc',
#      'value': '60'},
#     {'name': 'bmg_af_dft', 'value': '"5"'},
#     {'name': 'bili-login-state', 'value': '2'},
#     {'name': '__reporter-pb-sample-config',
#      'value': '{"444.8.live-room.chronos.init.before.check":50,"444.8.live-room.uam-player.welcome.failed":50,"333.1334.kv-init.error":1,"444.8.live-room.room-page.live-web-danmaku-tech-report":20}'},
#     {'name': 'wbi_img_urls',
#      'value': 'https://i0.hdslb.com/bfs/wbi/7cd084941338484aae1ad9425b84077c.png-https://i0.hdslb.com/bfs/wbi/4932caff0ff746eab6f01bf08b70ac45.png'}]},
#   {'origin': 'https://s1.hdslb.com',
#    'localStorage': [{'name': 'message-notify:source',
#      'value': 'search.bilibili.com/all_opx54r6tefm'},
#     {'name': 'message-notify:alive', 'value': '1755935013074'},
#     {'name': 'buvid-space:cross_buvid4',
#      'value': '7103D5D4-9CD2-A3F2-6F0C-E1EC3A754F8372323-025082315-ecwQDui1RrYNN5OfE3kNXA=='},
#     {'name': 'search_history:search_history',
#      'value': '[{"value":"AI","timestamp":1755933789082}]'},
#     {'name': 'search_history:migrated', 'value': '1'}]},
#   {'origin': 'https://message.bilibili.com',
#    'localStorage': [{'name': 'unreadApiRequestedBy427857At',
#      'value': '1755935003313'},
#     {'name': 'imMessageNotifyPush427857', 'value': '0'},
#     {'name': 'imSystemNotifyPush427857', 'value': '1'},
#     {'name': 'imNotifyCounts427857',
#      'value': '{"at_me":0,"reply_me":0,"praise_me":0,"notify_me":0,"message":113}'}]}]}
